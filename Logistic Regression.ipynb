# %% [markdown]
# ## DATA EXPLORATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv("Titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.pairplot(titanic)

# %%
titanic.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ## Dealing with missing Data

# %%
sns.heatmap(titanic.isnull(), yticklabels = False, cmap = "viridis")
#age
# Out:
# <Axes: >

# %%
titanic["Age"].dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
714/891
# Out:
# 0.8013468013468014

# %%
sns.distplot(titanic["Age"], bins = 30)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_21636\1740631801.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic["Age"], bins = 30)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot(data = titanic, x = "Pclass")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.boxplot(x = "Pclass", y = "Age", data = titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x = "Sex", y = "Age", data = titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
def imputation(empty):
    Age = empty[0]
    Pclass = empty[1]
    
    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        if Pclass == 2:
            return 29
        if Pclass == 3:
            return 24
    else:
        return Age

# %%
x = titanic[['Age', 'Pclass']].apply(imputation, axis = 1)
x
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_21636\500243567.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Age = empty[0]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_21636\500243567.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Pclass = empty[1]
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    24.0
# 889    26.0
# 890    32.0
# Length: 891, dtype: float64

# %%
x.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
x.dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    24.0
# 889    26.0
# 890    32.0
# Length: 891, dtype: float64

# %%
titanic['Age'] = x

# %%
sns.heatmap(titanic.isnull(), yticklabels = False, cmap = "viridis")
#age null values effected
# Out:
# <Axes: >

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## ANOTHER OPTION OF FILLING EMPTY DATA

# %%
df = titanic[['Age', 'Pclass']]

# %%
df

# %%
sns.heatmap(df.isnull(), yticklabels = False, cmap = "viridis")

# %%
null_value = df["Age"].isna()
null_value

# %%
selection_pool = df["Age"].dropna()

# %%
selection_pool.sample(2)

# %%
null_value.sum()

# %%
selection_pool.sample(n = null_value.sum(), replace = True)

# %%
selection_pool.sample(n = null_value.sum(), replace = True).values

# %%
df.loc[null_value, 'Age'] = selection_pool.sample(n = null_value.sum(), replace = True).values

# %%
df['Age'].isna()

# %%
sns.heatmap(df.isnull(), yticklabels = False, cmap = "viridis")

# %% [markdown]
# ## END

# %% [markdown]
# ## CARDINALITY AND FEATURE SELECTION

# %%
titanic.drop("Cabin", axis = 1, inplace = True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(titanic.nunique()) #titanic.nunique() will also work
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Embarked         3
# dtype: int64

# %%
titanic['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
#Get dummy variable = Replacing categorical values with numerical variable
pd.get_dummies(titanic['Sex'])
# Out:
#      female   male
# 0     False   True
# 1      True  False
# 2      True  False
# 3      True  False
# 4     False   True
# ..      ...    ...
# 886   False   True
# 887    True  False
# 888    True  False
# 889   False   True
# 890   False   True
#
# [891 rows x 2 columns]

# %%
sex = pd.get_dummies(titanic['Sex'], drop_first = True) 
#Drop first Makes it just one column since the sex can either be male or female
sex
# Out:
#       male
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 886   True
# 887  False
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %%
Embarked = pd.get_dummies(titanic['Embarked'])

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
titanic.drop(["PassengerId", "Name", "Ticket"], axis = 1, inplace = True)

# %%
titanic = pd.concat([titanic,sex,Embarked], axis = 1)
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked   male  \
# 0           0       3    male  22.0      1      0   7.2500        S   True
# 1           1       1  female  38.0      1      0  71.2833        C  False
# 2           1       3  female  26.0      0      0   7.9250        S  False
# 3           1       1  female  35.0      1      0  53.1000        S  False
# 4           0       3    male  35.0      0      0   8.0500        S   True
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S   True
# 887         1       1  female  19.0      0      0  30.0000        S  False
# 888         0       3  female  24.0      1      2  23.4500        S  False
# 889         1       1    male  26.0      0      0  30.0000        C   True
# 890         0       3    male  32.0      0      0   7.7500        Q   True
#
#          C      Q      S
# 0    False  False   True
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
#  8   male      891 non-null    bool
#  9   C         891 non-null    bool
#  10  Q         891 non-null    bool
#  11  S         891 non-null    bool
# dtypes: bool(4), float64(2), int64(4), object(2)
# memory usage: 59.3+ KB

# %%
titanic.drop(["Sex", "Embarked"], axis = 1, inplace = True)
#Since we have gotten the dummy values for them, we no longer need them

# %%
titanic
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare   male      C      Q      S
# 0           0       3  22.0      1      0   7.2500   True  False  False   True
# 1           1       1  38.0      1      0  71.2833  False   True  False  False
# 2           1       3  26.0      0      0   7.9250  False  False  False   True
# 3           1       1  35.0      1      0  53.1000  False  False  False   True
# 4           0       3  35.0      0      0   8.0500   True  False  False   True
# ..        ...     ...   ...    ...    ...      ...    ...    ...    ...    ...
# 886         0       2  27.0      0      0  13.0000   True  False  False   True
# 887         1       1  19.0      0      0  30.0000  False  False  False   True
# 888         0       3  24.0      1      2  23.4500  False  False  False   True
# 889         1       1  26.0      0      0  30.0000   True   True  False  False
# 890         0       3  32.0      0      0   7.7500   True  False   True  False
#
# [891 rows x 10 columns]

# %%
titanic[["male", "C", "Q", "S"]] = titanic[["male", "C", "Q", "S"]].astype(int)

# %%
titanic
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  male  C  Q  S
# 0           0       3  22.0      1      0   7.2500     1  0  0  1
# 1           1       1  38.0      1      0  71.2833     0  1  0  0
# 2           1       3  26.0      0      0   7.9250     0  0  0  1
# 3           1       1  35.0      1      0  53.1000     0  0  0  1
# 4           0       3  35.0      0      0   8.0500     1  0  0  1
# ..        ...     ...   ...    ...    ...      ...   ... .. .. ..
# 886         0       2  27.0      0      0  13.0000     1  0  0  1
# 887         1       1  19.0      0      0  30.0000     0  0  0  1
# 888         0       3  24.0      1      2  23.4500     0  0  0  1
# 889         1       1  26.0      0      0  30.0000     1  1  0  0
# 890         0       3  32.0      0      0   7.7500     1  0  1  0
#
# [891 rows x 10 columns]

# %% [markdown]
# ## BUILDING OUR MODEL

# %%
from sklearn.model_selection import train_test_split

# %%
titanic.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'male', 'C', 'Q',
#        'S'],
#       dtype='object')

# %%
y = titanic['Survived']
X = titanic[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'male', 'C', 'Q','S']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42, stratify = y)

# %%
from sklearn.linear_model import LogisticRegression

# %%
#initialize
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train, y_train)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction = logmodel.predict(X_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %%
classification_report(y_test, prediction)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.82      0.85      0.83       137\n           1       0.74      0.71      0.73        86\n\n    accuracy                           0.79       223\n   macro avg       0.78      0.78      0.78       223\nweighted avg       0.79      0.79      0.79       223\n'

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       137
#            1       0.74      0.71      0.73        86
#
#     accuracy                           0.79       223
#    macro avg       0.78      0.78      0.78       223
# weighted avg       0.79      0.79      0.79       223

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, prediction, labels = logmodel.classes_)
# Out:
# array([[116,  21],
#        [ 25,  61]])

# %%
cm = confusion_matrix(y_test, prediction, labels = logmodel.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = logmodel.classes_)

# %%
disp.plot()
